# %% [markdown]
# # Упражнение №1 по анализу данных
#
# Это **ячейка ** с текстом.
#
# /content/drive/MyDrive/Colab Notebooks/students.csv
# /content/drive/MyDrive/Colab Notebooks/Stepik_Анализ данных_task1.ipynb

# %%
print('Hello world')
# Out:
# Hello world

# %%
#вычсления для задачи с курса
15600*1.09*1.16
# Out:
# 19724.64

# %%
#import frameworks
import pandas as pd

# %%
#Загрузка наших данных
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/students.csv', delimiter=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
#Получить размеры таблицы
df.shape
# Out:
# (186, 48)

# %%
df
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0     20     170         40              2           2002            100
# 1     22     191         43              7           2000            307
# 2     21     172         41              4           2000            186
# 3     19     168         38              2           2003            604
# 4     23     159         36              1           1998            144
# ..   ...     ...        ...            ...            ...            ...
# 181   23     168         39              7           1999            228
# 182   19     169         38              1           2003              0
# 183   18     161         37              2           2003             11
# 184   19     169         41              1           2003             22
# 185   18     164         39              2           2003            500
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# ...

# %%
#Выводим первые 5 строк. Если хотим больше строк, то в скобки вводим столько, сколько надо
df.head(13)
# Out:
#     Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0    20     170         40              2           2002            100
# 1    22     191         43              7           2000            307
# 2    21     172         41              4           2000            186
# 3    19     168         38              2           2003            604
# 4    23     159         36              1           1998            144
# 5    18     177         40              2           2003            100
# 6    18     180         42              0           2004              0
# 7    19     180         48              1           2003              5
# 8    20     185         46              3           2002             28
# 9    22     168         38              6           2000            297
# 10   20     158         35              4           2001           1000
# 11   19     183         44              2           2002             40
# ...

# %%
#Выводим последние 5 строк. Если хотим больше строк, то в скобки вводим столько, сколько надо
df.tail(18)

# %%
#Обращение к конкретному столбцу с признаком Age
df['Age']

# %%
df['Age'].describe()
# Out:
# count    186.000000
# mean      20.688172
# std        3.468713
# min       17.000000
# 25%       19.000000
# 50%       20.000000
# 75%       21.000000
# max       55.000000
# Name: Age, dtype: float64

# %%
df['Growth'].describe()
# Out:
# count    186.000000
# mean     170.661290
# std        9.055881
# min      153.000000
# 25%      164.000000
# 50%      169.000000
# 75%      178.000000
# max      197.000000
# Name: Growth, dtype: float64

# %%
#Это категориальная функция, т.к. пол не числовой показатель, для более лучшей отработки необходимо использовать след. функцию
df['Sex'].describe()
# Out:
# count         186
# unique          2
# top       женский
# freq          120
# Name: Sex, dtype: object

# %%
df['Sex'].value_counts()

# %%
df['Chocolate'].value_counts()

# %%
#Метод,  применяемый для анализа всей таблички сразу. Кроме категориальных признаков.
df.describe()
